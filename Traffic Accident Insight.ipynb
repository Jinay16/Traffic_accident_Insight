# %% [markdown]
# # Import Data

# %%
import pandas as pd

file_path = r"C:\Users\JASH PRAJAPATI\Desktop\Road Accident Data.xlsx"

sheet_names = pd.ExcelFile(r"C:\Users\JASH PRAJAPATI\Desktop\Road Accident Data.xlsx").sheet_names
print("Sheets found:", sheet_names)

combined_df = pd.concat(pd.read_excel(file_path, sheet_name=None), ignore_index=True)

combined_df.head()
# Out:
# Sheets found: ['RAW DATA']
#   Accident_Index Accident Date Month Day_of_Week  Year  \
# 0  200901BS70001    2021-01-01   Jan    Thursday  2021
# 1  200901BS70002    2021-01-05   Jan      Monday  2021
# 2  200901BS70003    2021-01-04   Jan      Sunday  2021
# 3  200901BS70004    2021-01-05   Jan      Monday  2021
# 4  200901BS70005    2021-01-06   Jan     Tuesday  2021
#
#            Junction_Control          Junction_Detail Accident_Severity  \
# 0  Give way or uncontrolled  T or staggered junction           Serious
# 1  Give way or uncontrolled               Crossroads           Serious
# 2  Give way or uncontrolled  T or staggered junction            Slight
# 3       Auto traffic signal  T or staggered junction           Serious
# 4       Auto traffic signal               Crossroads           Serious
#
#     Latitude       Light_Conditions  ... Number_of_Casualties  \
# 0  51.512273               Daylight  ...                    1
# ...

# %% [markdown]
# # Display basic info

# %%
import pandas as pd

# Load your dataset first
df = pd.read_excel(r"C:\Users\JASH PRAJAPATI\Desktop\Road Accident Data.xlsx")   # Replace with your actual file name or path

# Now these commands will work
print("Dataset Shape:", df.shape)
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Shape: (307973, 23)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307973 entries, 0 to 307972
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident_Index              307973 non-null  object
#  1   Accident Date               307973 non-null  datetime64[ns]
#  2   Month                       307973 non-null  object
#  3   Day_of_Week                 307973 non-null  object
#  4   Year                        307973 non-null  int64
#  5   Junction_Control            307973 non-null  object
#  6   Junction_Detail             307973 non-null  object
#  7   Accident_Severity           307973 non-null  object
#  8   Latitude                    307973 non-null  float64
#  9   Light_Conditions            307973 non-null  object
#  10  Local_Authority_(District)  307973 non-null  object
#  11  Carriageway_Hazards         5424 non-null    object
# ...

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\JASH PRAJAPATI\Desktop\Road Accident Data.xlsx")
df.columns.tolist()
# Out:
# ['Accident_Index',
#  'Accident Date',
#  'Month',
#  'Day_of_Week',
#  'Year',
#  'Junction_Control',
#  'Junction_Detail',
#  'Accident_Severity',
#  'Latitude',
#  'Light_Conditions',
#  'Local_Authority_(District)',
#  'Carriageway_Hazards',
#  'Longitude',
#  'Number_of_Casualties',
#  'Number_of_Vehicles',
#  'Police_Force',
#  'Road_Surface_Conditions',
#  'Road_Type',
#  'Speed_limit',
#  'Time',
#  'Urban_or_Rural_Area',
#  'Weather_Conditions',
#  'Vehicle_Type']

# %% [markdown]
# # Display first few rows

# %%
print("\nFirst 5 Rows:")
df.head()
# Out:
# First 5 Rows:
#   Accident_Index Accident Date Month Day_of_Week  Year  \
# 0  200901BS70001    2021-01-01   Jan    Thursday  2021
# 1  200901BS70002    2021-01-05   Jan      Monday  2021
# 2  200901BS70003    2021-01-04   Jan      Sunday  2021
# 3  200901BS70004    2021-01-05   Jan      Monday  2021
# 4  200901BS70005    2021-01-06   Jan     Tuesday  2021
#
#            Junction_Control          Junction_Detail Accident_Severity  \
# 0  Give way or uncontrolled  T or staggered junction           Serious
# 1  Give way or uncontrolled               Crossroads           Serious
# 2  Give way or uncontrolled  T or staggered junction            Slight
# 3       Auto traffic signal  T or staggered junction           Serious
# 4       Auto traffic signal               Crossroads           Serious
#
#     Latitude       Light_Conditions  ... Number_of_Casualties  \
# 0  51.512273               Daylight  ...                    1
# ...

# %% [markdown]
# # Display last few rows

# %%
print("\nLast 5 Rows:")
df.tail()
# Out:
# Last 5 Rows:
#        Accident_Index Accident Date Month Day_of_Week  Year  \
# 307968  201091NM01760    2022-02-18   Feb    Thursday  2022
# 307969  201091NM01881    2022-02-21   Feb      Sunday  2022
# 307970  201091NM01935    2022-02-23   Feb     Tuesday  2022
# 307971  201091NM01964    2022-02-23   Feb     Tuesday  2022
# 307972  201091NM02142    2022-02-28   Feb      Sunday  2022
#
#                     Junction_Control                      Junction_Detail  \
# 307968  Data missing or out of range  Not at junction or within 20 metres
# 307969  Data missing or out of range  Not at junction or within 20 metres
# 307970      Give way or uncontrolled              T or staggered junction
# 307971      Give way or uncontrolled              T or staggered junction
# 307972      Give way or uncontrolled              T or staggered junction
#
#        Accident_Severity   Latitude        Light_Conditions  ...  \
# 307968            Slight  57.374005                Daylight  ...
# ...

# %% [markdown]
# # Data Preparation

# %%
# Check total missing values per column
df.isnull().sum()
# Out:
# Accident_Index                     0
# Accident Date                      0
# Month                              0
# Day_of_Week                        0
# Year                               0
# Junction_Control                   0
# Junction_Detail                    0
# Accident_Severity                  0
# Latitude                           0
# Light_Conditions                   0
# Local_Authority_(District)         0
# Carriageway_Hazards           302549
# Longitude                          0
# Number_of_Casualties               0
# Number_of_Vehicles                 0
# Police_Force                       0
# Road_Surface_Conditions          317
# Road_Type                       1534
# Speed_limit                        0
# Time                              17
# Urban_or_Rural_Area                0
# Weather_Conditions              6057
# Vehicle_Type                       0
# dtype: int64

# %%
df.drop(columns=['Carriageway_Hazards', 'Time'], inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#       Accident_Index Accident Date Month Day_of_Week  Year  \
# 50483  2010000000000    2021-01-06   Jan     Tuesday  2021
#
#                    Junction_Control                      Junction_Detail  \
# 50483  Data missing or out of range  Not at junction or within 20 metres
#
#       Accident_Severity   Latitude Light_Conditions  ... Number_of_Casualties  \
# 50483            Slight  53.648498         Daylight  ...                    1
#
#       Number_of_Vehicles    Police_Force  Road_Surface_Conditions  \
# 50483                  1  West Yorkshire             Frost or ice
#
#                 Road_Type Speed_limit      Time Urban_or_Rural_Area  \
# 50483  Single carriageway          50  16:35:00               Rural
#
#        Weather_Conditions Vehicle_Type
# 50483  Fine no high winds          Car
#
# [1 rows x 23 columns]

# %%
import pandas as pd

def get_categorical_columns(dataset):
    """
    Retrieves categorical columns from the dataset
    and displays their unique values.
    """
    # Select categorical columns (object or category types)
    categorical_columns = dataset.select_dtypes(include=['object', 'category'])
    
    # Get unique values for each categorical column
    unique_values_cat_cols = categorical_columns.apply(lambda x: x.unique())
    
    return unique_values_cat_cols

# Run the function on your dataframe
unique_values_count = get_categorical_columns(df)

# Display result
print(unique_values_count)
# Out:
# Accident_Index                [200901BS70001, 200901BS70002, 200901BS70003, ...
# Month                         [Jan, Feb, Mar, Apr, May, Jun, Aug, Jul, Sep, ...
# Day_of_Week                   [Thursday, Monday, Sunday, Tuesday, Friday, We...
# Junction_Control              [Give way or uncontrolled, Auto traffic signal...
# Junction_Detail               [T or staggered junction, Crossroads, Not at j...
# Accident_Severity                                      [Serious, Slight, Fatal]
# Light_Conditions              [Daylight, Darkness - lights lit, Darkness - l...
# Local_Authority_(District)    [Kensington and Chelsea, Hammersmith and Fulha...
# Carriageway_Hazards           [nan, Pedestrian in carriageway - not injured,...
# Police_Force                  [Metropolitan Police, City of London, Cumbria,...
# Road_Surface_Conditions       [Dry, Wet or damp, Frost or ice, Snow, Flood o...
# Road_Type                     [One way street, Single carriageway, Dual carr...
# ...

# %% [markdown]
# # Check Unique Value

# %%
print("\nUnique Values Per Column:")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Unique Values Per Column:
# Accident_Index: 193173 unique values
# Accident Date: 730 unique values
# Month: 12 unique values
# Day_of_Week: 7 unique values
# Year: 2 unique values
# Junction_Control: 6 unique values
# Junction_Detail: 9 unique values
# Accident_Severity: 3 unique values
# Latitude: 258556 unique values
# Light_Conditions: 5 unique values
# Local_Authority_(District): 422 unique values
# Longitude: 263828 unique values
# Number_of_Casualties: 28 unique values
# Number_of_Vehicles: 17 unique values
# Police_Force: 51 unique values
# Road_Surface_Conditions: 5 unique values
# Road_Type: 5 unique values
# Speed_limit: 8 unique values
# Urban_or_Rural_Area: 2 unique values
# Weather_Conditions: 8 unique values
# Vehicle_Type: 15 unique values

# %% [markdown]
# # Summary statistics for numerical columns

# %%
print("\nSummary Statistics:")
df.describe()
# Out:
# Summary Statistics:
#                        Accident Date           Year       Latitude  \
# count                         300512  300512.000000  300512.000000
# mean   2021-12-24 08:17:29.504845056    2021.469865      52.485568
# min              2021-01-01 00:00:00    2021.000000      49.914488
# 25%              2021-06-29 00:00:00    2021.000000      51.484873
# 50%              2021-12-09 00:00:00    2021.000000      52.212485
# 75%              2022-06-25 00:00:00    2022.000000      53.416004
# max              2022-12-31 00:00:00    2022.000000      60.598055
# std                              NaN       0.499092       1.341740
#
#            Longitude  Number_of_Casualties  Number_of_Vehicles    Speed_limit
# count  300512.000000         300512.000000       300512.000000  300512.000000
# mean       -1.361957              1.359443            1.830513      38.932921
# min        -7.516225              1.000000            1.000000      10.000000
# ...

# %% [markdown]
# # Plotting the Categorical Columns

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r"C:\Users\JASH PRAJAPATI\Desktop\Road Accident Data.xlsx")

categorical_cols = [
    "Month", "Day_of_Week", "Junction_Control",  
    "Accident_Severity", "Light_Conditions",
    "Road_Surface_Conditions", 
    "Road_Type", "Urban_or_Rural_Area"
]

plt.figure(figsize=(15,20))
for i, col in enumerate(categorical_cols):  
    plt.subplot(6, 2, i + 1)
    
    sns.countplot(x=df[col], palette="viridis", order=df[col].value_counts().index)
    plt.xticks(rotation=60)
    plt.title(f"Distribution of {col}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plotting the Numerical Columns

# %%
numerical_cols = ["Year", "Number_of_Casualties", "Number_of_Vehicles", "Speed_limit"]

plt.figure(figsize=(12, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(3, 2, i + 1)
    sns.boxplot(y=df[col], palette="coolwarm")
    plt.title(f"Boxplot of {col}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plotting the Severity

# %%
plt.figure(figsize=(8, 5))
ax = sns.countplot(x=df["Accident_Severity"], palette="Set2", order=["Fatal", "Serious", "Slight"])
for p in ax.patches:
        ax.annotate(f'{p.get_height():.0f}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', 
                    fontsize=12, color='black', 
                    xytext=(0, 5), textcoords='offset points')
    
plt.xlabel('Severity', fontsize=12)
plt.ylabel('No of Accidents', fontsize=12)
plt.title("Accident Severity Distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plotting the Light Conditions

# %%
plt.figure(figsize=(10, 8))
ax = sns.countplot(x=df["Light_Conditions"], palette="deep")
for p in ax.patches:
        ax.annotate(f'{p.get_height():.0f}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', 
                    fontsize=12, color='black', 
                    xytext=(0, 5), textcoords='offset points')
    
plt.xticks(rotation=45)
plt.xlabel('Light Conditions', fontsize=12)
plt.ylabel('No of Accidents', fontsize=12)
plt.title("Light Conditions Distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plotting the Road Surface Conditions

# %%
plt.figure(figsize=(10, 8))
ax = sns.countplot(x=df["Road_Surface_Conditions"], palette="muted")
for p in ax.patches:
        ax.annotate(f'{p.get_height():.0f}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', 
                    fontsize=12, color='black', 
                    xytext=(0, 5), textcoords='offset points')
    
plt.xticks(rotation=45)
plt.xlabel('Road Surface Conditions', fontsize=12)
plt.ylabel('No of Accidents', fontsize=12)
plt.title("Road Surface Conditions Distribution")
plt.tight_layout()
plt.show()
